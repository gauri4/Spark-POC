# %%
# Prepare data.
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
Data = [("James,A,Smith","36636","M",3000),
    ("Michael,Rose,Jones","40288","M",4000),
    ("Robert, B,Williams","42114","M",4000),
    ("Maria,Anne,Jones","39192","F",4000),
    ("Jen,Mary,Brown","","F",-1)
  ]
Schema = StructType([StructField("name",StringType(),True),
                     StructField("id",StringType(),True),
                     StructField("gender",StringType(),True),
                     StructField("salary",IntegerType(),True)])

# %%
# Create DataFrame.
df = spark.createDataFrame(data = Data, schema = Schema)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>id</th><th>gender</th><th>salary</th></tr></thead><tbody><tr><td>James,A,Smith</td><td>36636</td><td>M</td><td>3000</td></tr><tr><td>Michael,Rose,Jones</td><td>40288</td><td>M</td><td>4000</td></tr><tr><td>Robert, B,Williams</td><td>42114</td><td>M</td><td>4000</td></tr><tr><td>Maria,Anne,Jones</td><td>39192</td><td>F</td><td>4000</td></tr><tr><td>Jen,Mary,Brown</td><td></td><td>F</td><td>-1</td></tr></tbody></table></div>

# %%
# Split Column name based on ",".
from pyspark.sql.functions import split,col
df_name = df.select("*",split(col("name"),",").alias("NameArray"))
df_name.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>id</th><th>gender</th><th>salary</th><th>NameArray</th></tr></thead><tbody><tr><td>James,A,Smith</td><td>36636</td><td>M</td><td>3000</td><td>List(James, A, Smith)</td></tr><tr><td>Michael,Rose,Jones</td><td>40288</td><td>M</td><td>4000</td><td>List(Michael, Rose, Jones)</td></tr><tr><td>Robert, B,Williams</td><td>42114</td><td>M</td><td>4000</td><td>List(Robert,  B, Williams)</td></tr><tr><td>Maria,Anne,Jones</td><td>39192</td><td>F</td><td>4000</td><td>List(Maria, Anne, Jones)</td></tr><tr><td>Jen,Mary,Brown</td><td></td><td>F</td><td>-1</td><td>List(Jen, Mary, Brown)</td></tr></tbody></table></div>

# %%
# Add Firstname, Middlename, Lastname columns.
final_df = df_name.withColumn("FirstName",df_name.NameArray[0]) \
                  .withColumn("MiddleName",df_name.NameArray[1]) \
                  .withColumn("LastName",df_name.NameArray[2]).drop("NameArray") 
final_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>id</th><th>gender</th><th>salary</th><th>FirstName</th><th>MiddleName</th><th>LastName</th></tr></thead><tbody><tr><td>James,A,Smith</td><td>36636</td><td>M</td><td>3000</td><td>James</td><td>A</td><td>Smith</td></tr><tr><td>Michael,Rose,Jones</td><td>40288</td><td>M</td><td>4000</td><td>Michael</td><td>Rose</td><td>Jones</td></tr><tr><td>Robert, B,Williams</td><td>42114</td><td>M</td><td>4000</td><td>Robert</td><td> B</td><td>Williams</td></tr><tr><td>Maria,Anne,Jones</td><td>39192</td><td>F</td><td>4000</td><td>Maria</td><td>Anne</td><td>Jones</td></tr><tr><td>Jen,Mary,Brown</td><td></td><td>F</td><td>-1</td><td>Jen</td><td>Mary</td><td>Brown</td></tr></tbody></table></div>
